# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajspeaks/Bengali-Text-Visualization-using-Word2Vec-Model/blob/main/Bengali_Text_Visualization_using_Word2Vec_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bengali Text-Visualization using Word2Vec Model**

# %% [markdown]
# Part 1:  "History of Bengal". Data collected from Wikipedia.

# %%
import gensim
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
import matplotlib.font_manager as fm

# %%
t1=input("Enter Text:")
# Out:
# Enter Text:বাংলার ইতিহাস বলতে অধুনা বাংলাদেশ, ভারতের পশ্চিমবঙ্গ, ত্রিপুরা এবং আসামের বরাক উপত্যকার বিগত চার সহস্রাব্দের ইতিহাসকে বোঝায়। গঙ্গা ও ব্রহ্মপুত্র নদ এক অর্থে বাংলাকে ভারতের মূল ভূখণ্ড থেকে বিচ্ছিন্ন করে রেখেছিল। কিন্তু তা সত্ত্বেও ভারতের ইতিহাসে বাংলা এক গুরুত্বপূর্ণ ভূমিকা গ্রহণ করে। প্রাচীন রোমান ও গ্রিকদের কাছে এই অঞ্চল গঙ্গারিডাই নামে পরিচিত ছিল। চার সহস্রাব্দ পূর্বে বাংলায় সভ্যতার ক্রমবিকাশ শুরু হয়। প্রাচীন গ্রিক ও রোমান ভাষায় এই অঞ্চলকে গঙ্গারিডই নামে উল্লেখ করা হয়েছে। দক্ষিণ এশিয়ার ইতিহাসে বাংলা সর্বদাই একটি গুরুত্বপূর্ণ ভূমিকা পালন করেছে। প্রাচীন বাংলা কয়েকটি জনপদে বিভক্ত ছিল এবং বেশ কিছু প্রাচীন নগরের বৈদিক যুগে পত্তন এখানে হয়েছিল বলে ধারণা করা হয়। প্রাচীন বাংলার অধিবাসীরা ভারত মহাসাগরে অবস্থিত বিভিন্ন দ্বীপে উপনিবেশ স্থাপন করেছিল। পারস্য, আরব এবং ভূমধ্যসাগরীয় অঞ্চলের সাথে বাংলার দৃঢ় বাণিজ্যিক সম্পর্ক ছিল। এই অঞ্চল মৌর্য ও গুপ্ত সাম্রাজ্য সহ আরও অনেক ভারতীয় সাম্রাজ্যের অংশ ছিল। বাংলা বিভিন্ন সময়ে আঞ্চলিক শাসকদের রাজধানী রূপে স্বীকৃতি পেয়েছে। প্রাচীন দ
# ...

# %%
import re
whitespace = re.compile(u"[\s\u0020\u00a0\u1680\u180e\u202f\u205f\u3000\u2000-\u200a]+", re.UNICODE)
bangla_fullstop = u"\u0964"
punctSeq   = u"['\"“”‘’]+|[.?!,…]+|[:;]+"
punc = u"[(),$%^&*+={}\[\]:\"|\'\~`<>/,€¦!?½£¶™¼©⅐⅑⅒⅓⅔⅕⅖⅗⅘⅙⅚⅛⅜⅝⅞⅟↉¤¿º;-]+"
t1= whitespace.sub(" ",t1).strip()
t1 = re.sub(punctSeq, " ", t1)
t1 = re.sub(bangla_fullstop, " ",t1)
t1 = re.sub(punc, " ", t1)

# %%
print(t1)
# Out:
# বাংলার ইতিহাস বলতে অধুনা বাংলাদেশ  ভারতের পশ্চিমবঙ্গ  ত্রিপুরা এবং আসামের বরাক উপত্যকার বিগত চার সহস্রাব্দের ইতিহাসকে বোঝায়  গঙ্গা ও ব্রহ্মপুত্র নদ এক অর্থে বাংলাকে ভারতের মূল ভূখণ্ড থেকে বিচ্ছিন্ন করে রেখেছিল  কিন্তু তা সত্ত্বেও ভারতের ইতিহাসে বাংলা এক গুরুত্বপূর্ণ ভূমিকা গ্রহণ করে  প্রাচীন রোমান ও গ্রিকদের কাছে এই অঞ্চল গঙ্গারিডাই নামে পরিচিত ছিল  চার সহস্রাব্দ পূর্বে বাংলায় সভ্যতার ক্রমবিকাশ শুরু হয়  প্রাচীন গ্রিক ও রোমান ভাষায় এই অঞ্চলকে গঙ্গারিডই নামে উল্লেখ করা হয়েছে  দক্ষিণ এশিয়ার ইতিহাসে বাংলা সর্বদাই একটি গুরুত্বপূর্ণ ভূমিকা পালন করেছে  প্রাচীন বাংলা কয়েকটি জনপদে বিভক্ত ছিল এবং বেশ কিছু প্রাচীন নগরের বৈদিক যুগে পত্তন এখানে হয়েছিল বলে ধারণা করা হয়  প্রাচীন বাংলার অধিবাসীরা ভারত মহাসাগরে অবস্থিত বিভিন্ন দ্বীপে উপনিবেশ স্থাপন করেছিল  পারস্য  আরব এবং ভূমধ্যসাগরীয় অঞ্চলের সাথে বাংলার দৃঢ় বাণিজ্যিক সম্পর্ক ছিল  এই অঞ্চল মৌর্য ও গুপ্ত সাম্রাজ্য সহ আরও অনেক ভারতীয় সাম্রাজ্যের অংশ ছিল  বাংলা বিভিন্ন সময়ে আঞ্চলিক শাসকদের রাজধানী রূপে স্বীকৃতি পেয়েছে  প্রাচীন দুর্গ নগর গৌ
# ...

# %%
doc=[t1.split()]

# %%
model = Word2Vec(doc, min_count=1)

# %%
model.train(doc, total_examples=len(doc), epochs=model.iter)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (1124, 1640)

# %%
x= model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
prop = fm.FontProperties(fname='AmarBangla.ttf')
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]),fontproperties=prop)
pyplot.show()

# %% [markdown]
# Part 2: "Independence Day of India. History of Independencec of India". Data collected from Wikipedia.

# %%
t2=input("Enter Text:")
# Out:
# Enter Text:স্বাধীনতা দিবস হল ভারতীয় প্রজাতন্ত্রের একটি জাতীয় দিবস। ১৯৪৭ সালের ১৫ আগস্ট ভারত ব্রিটিশ রাজশক্তির শাসনকর্তৃত্ব থেকে মুক্ত হয়ে স্বাধীনতা অর্জন করেছিল। সেই ঘটনাটিকে স্মরণীয় করে রাখার জন্য প্রতি বছর ১৫অগাস্ট তারিখটি ভারতে স্বাধীনতা দিবস হিসেবে পালন করা হয়। নেতাজি সুভাষচন্দ্র বসু নেতৃত্ব আজাদ হিন্দ ফৌজ যে ভাবে ব্রিটিশ সাম্রাজ্যবাদের ওপর আঘাত হানে , তাই ফলে ব্রিটিশ নৌ-বাহিনী অনুপ্রেরণা হয়ে বিদ্রোহী হয়ে ওঠে, এই জন্য ব্রিটিশ সরকার প্রধানত ভয় পেয়ে ভারতবর্ষ ছেড়ে যেতে বাধ্য হয়েছিল। মূলতঃ ব্রিটিশ সরকার স্বীকার করে নিয়েছেন দ্বিতীয় বিশ্বযুদ্ধ জয়লাভ করলেও , তাদের মনে মধ্যে নেতাজি সুভাষচন্দ্র বসু ভয় ডুকে গিয়েছিল। যার ফলে ভারত স্বাধীনতা অর্জন করেছিল। স্বাধীনতার ঠিক পূর্ব-মুহুর্তে ব্রিটিশ ভারতীয় সাম্রাজ্য ধর্মের ভিত্তিতে বিভাজিত হয় এবং তার ফলে ভারত ও পাকিস্তান অধিরাজ্যের জন্ম ঘটে। দেশভাগের সময় সাম্প্রদায়িক দাঙ্গায় প্রচুর ক্ষয়ক্ষতির ঘটনা ঘটে। অনেক মানুষ প্রাণ হারান এবং ১ কোটি ৫০ লক্ষেরও বেশি মানুষ বাস্তুহারা হন। ১৯৪৭ সালের ১৫ অগস্ট জওহরলাল নেহেরু ভারতের প্রথম প্রধানমন
# ...

# %%
import re
whitespace = re.compile(u"[\s\u0020\u00a0\u1680\u180e\u202f\u205f\u3000\u2000-\u200a]+", re.UNICODE)
bangla_fullstop = u"\u0964"
punctSeq   = u"['\"“”‘’]+|[.?!,…]+|[:;]+"
punc = u"[(),$%^&*+={}\[\]:\"|\'\~`<>/,€¦!?½£¶™¼©⅐⅑⅒⅓⅔⅕⅖⅗⅘⅙⅚⅛⅜⅝⅞⅟↉¤¿º;-]+"
t2= whitespace.sub(" ",t2).strip()
t2 = re.sub(punctSeq, " ", t2)
t2 = re.sub(bangla_fullstop, " ",t2)
t2 = re.sub(punc, " ", t2)

# %%
print(t2)
# Out:
# স্বাধীনতা দিবস হল ভারতীয় প্রজাতন্ত্রের একটি জাতীয় দিবস  ১৯৪৭ সালের ১৫ আগস্ট ভারত ব্রিটিশ রাজশক্তির শাসনকর্তৃত্ব থেকে মুক্ত হয়ে স্বাধীনতা অর্জন করেছিল  সেই ঘটনাটিকে স্মরণীয় করে রাখার জন্য প্রতি বছর ১৫অগাস্ট তারিখটি ভারতে স্বাধীনতা দিবস হিসেবে পালন করা হয়  নেতাজি সুভাষচন্দ্র বসু নেতৃত্ব আজাদ হিন্দ ফৌজ যে ভাবে ব্রিটিশ সাম্রাজ্যবাদের ওপর আঘাত হানে   তাই ফলে ব্রিটিশ নৌ বাহিনী অনুপ্রেরণা হয়ে বিদ্রোহী হয়ে ওঠে  এই জন্য ব্রিটিশ সরকার প্রধানত ভয় পেয়ে ভারতবর্ষ ছেড়ে যেতে বাধ্য হয়েছিল  মূলতঃ ব্রিটিশ সরকার স্বীকার করে নিয়েছেন দ্বিতীয় বিশ্বযুদ্ধ জয়লাভ করলেও   তাদের মনে মধ্যে নেতাজি সুভাষচন্দ্র বসু ভয় ডুকে গিয়েছিল  যার ফলে ভারত স্বাধীনতা অর্জন করেছিল  স্বাধীনতার ঠিক পূর্ব মুহুর্তে ব্রিটিশ ভারতীয় সাম্রাজ্য ধর্মের ভিত্তিতে বিভাজিত হয় এবং তার ফলে ভারত ও পাকিস্তান অধিরাজ্যের জন্ম ঘটে  দেশভাগের সময় সাম্প্রদায়িক দাঙ্গায় প্রচুর ক্ষয়ক্ষতির ঘটনা ঘটে  অনেক মানুষ প্রাণ হারান এবং ১ কোটি ৫০ লক্ষেরও বেশি মানুষ বাস্তুহারা হন  ১৯৪৭ সালের ১৫ অগস্ট জওহরলাল নেহেরু ভারতের প্রথম প্রধানমন্ত্রী পদে শ
# ...

# %%
doc2=[t2.split()]

# %%
model2 = Word2Vec(doc2, min_count=1)

# %%
model2.train(doc2, total_examples=len(doc), epochs=model2.iter)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (2152, 2810)

# %%
x= model2[model2.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
pyplot.scatter(result[:, 0], result[:, 1])
words2 = list(model2.wv.vocab)
prop = fm.FontProperties(fname='AmarBangla.ttf')
for i, word in enumerate(words2):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]),fontproperties=prop)
pyplot.show()
